# %%
# Data-Augmentation-predict 

# 本次使用的模型數據如下：
# Test loss: 0.10623177140951157
# Test accuracy: 0.9611762166023254

# %%
show_train_history('accuracy','val_accuracy')
show_train_history('loss','val_loss')

# %%
# Confusion matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
np.set_printoptions(suppress=True)
sns.set()
mat = confusion_matrix(y_Test, prediction)
sns.heatmap(mat, square=True, annot=True, cbar=False, fmt='g')
plt.xlabel('Predicted value')
plt.ylabel('True value');

# %%
# 使用上述的 model，對 malaria做疾病預測

# %%
# load model
from tensorflow.python.keras.models import load_model
model2 = load_model('./day10-20211013channels.h5')

# %%
# predict
import matplotlib.pyplot as plt
sample = plt.imread('./train/00000.jpg') #<-- image filename
sample_detect = sample.reshape(1, 128, 128, 3).astype('float32')
print(model2.predict(sample_detect))
plt.imshow(sample)
plt.show()
# Out:
# [[0.01131999 0.98868   ]]
